# %%
import yfinance as yf
import pandas as pd
# For data manipulation
from urllib.request import urlopen, Request
# To extract fundamental data
from bs4 import BeautifulSoup
def fundamental_metric(soup, metric):
    return soup.find(text = metric).find_next(class_='snapshot-td2').text
def get_fundamental_data(df):
    for symbol in df.index:
        try:
            url = ("http://finviz.com/quote.ashx?t=" + symbol.lower())
            soup = bs(requests.get(url).content) 
            for m in df.columns:                
                df.loc[symbol,m] = fundamental_metric(soup,m)                
        except Exception as e:
            print (symbol, 'not found')
    return df
stock_list = ['AMZN','GOOG','PG','KO','IBM','DG','XOM','KO','PEP','MT','NL','LPL']
metric = ['P/B',
'P/E',
'Forward P/E',
'PEG',
'Debt/Eq',
'EPS (ttm)',
'Dividend %',
'ROE',
'ROI',
'EPS Q/Q',
'Insider Own'
]
sp500_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['Symbol'].tolist()

df = pd.DataFrame(index=sp500_tickers,columns=metric)
df = get_fundamental_data(df)
def fundamental_factor_model_sp500(df):
    
    # Calculate the PE ratio, PB ratio, and PS ratio for each company
    pe_ratios = df['P/E']
    fpe_ratios = df['Forward P/E']
    peg_ratios = df['PEG']
    roi_ratios = df['ROI']

    # Combine the ratios into a single DataFrame
    ratios = pd.concat([pe_ratios, fpe_ratios, 
                        peg_ratios,roi_ratios], axis=1)
    ratios.columns = ['PE Ratio', 'FPE Ratio', 'PEG Ratio', 'ROI Ratio']

    # Calculate the composite score as a weighted average of the three ratios
    ratios['Composite Score'] = (0.25 * ratios['PE Ratio']) + (0.25 * ratios['FPE Ratio']) + (0.25 * ratios['PEG Ratio'])+ (0.25 * ratios['ROI Ratio'])

    # Sort the companies by composite score
    sorted_ratios = ratios.sort_values(by='Composite Score')

    # Determine the number of companies in the top and bottom 10% of the sorted list
    num_companies = len(sorted_ratios)
    top_5_pct = int(num_companies * 0.05)
    bottom_5_pct = int(num_companies * 0.95)

    # Select the top and bottom 10% of companies for a long-short portfolio
    top_stocks = sorted_ratios.index[:top_5_pct].tolist()
    bottom_stocks = sorted_ratios.index[bottom_5_pct:].tolist()

    return top_stocks, bottom_stocks
# Calculate the top and bottom companies for a long-short portfolio for the month of March 2023

top_stocks, bottom_stocks = fundamental_factor_model_sp500(df)
print("Top Stocks:", top_stocks)
print("Bottom Stocks:", bottom_stocks)
# Out:
# MMM not found
# AOS not found
# ABT not found
# ABBV not found
# ACN not found
# ATVI not found
# ADM not found
# ADBE not found
# ADP not found
# AAP not found
# AES not found
# AFL not found
# A not found
# APD not found
# AKAM not found
# ALK not found
# ALB not found
# ARE not found
# ALGN not found
# ALLE not found
# LNT not found
# ALL not found
# GOOGL not found
# GOOG not found
# MO not found
# AMZN not found
# AMCR not found
# AMD not found
# AEE not found
# AAL not found
# AEP not found
# AXP not found
# AIG not found
# AMT not found
# AWK not found
# AMP not found
# ABC not found
# AME not found
# AMGN not found
# APH not found
# ADI not found
# ANSS not found
# AON not found
# APA not found
# AAPL not found
# AMAT not found
# APTV not found
# ACGL not found
# ANET not found
# AJG not found
# AIZ not found
# T not found
# ATO not found
# ADSK not found
# AZO not found
# AVB not found
# AVY not found
# AXON not found
# BKR not found
# BALL not found
# BAC not found
# BBWI not found
# BAX not found
# BDX not found
# WRB not found
# BRK.B not found
# BBY not found
# BIO not found
# TECH not found
# BIIB not found
# BLK not found
# BK not found
# BA not found
# BKNG not found
# BWA not found
# BXP not found
# BSX not found
# BMY not found
# AVGO not found
# BR not found
# BRO not found
# BF.B not found
# BG not found
# CHRW not found
# CDNS not found
# CZR not found
# CPT not found
# CPB not found
# COF not found
# CAH not found
# KMX not found
# CCL not found
# CARR not found
# CTLT not found
# CAT not found
# CBOE not found
# CBRE not found
# CDW not found
# CE not found
# CNC not found
# CNP not found
# CDAY not found
# CF not found
# CRL not found
# SCHW not found
# CHTR not found
# CVX not found
# CMG not found
# CB not found
# CHD not found
# CI not found
# CINF not found
# CTAS not found
# CSCO not found
# C not found
# CFG not found
# CLX not found
# CME not found
# CMS not found
# KO not found
# CTSH not found
# CL not found
# CMCSA not found
# CMA not found
# CAG not found
# COP not found
# ED not found
# STZ not found
# CEG not found
# COO not found
# CPRT not found
# GLW not found
# CTVA not found
# CSGP not found
# COST not found
# CTRA not found
# CCI not found
# CSX not found
# CMI not found
# CVS not found
# DHI not found
# DHR not found
# DRI not found
# DVA not found
# DE not found
# DAL not found
# XRAY not found
# DVN not found
# DXCM not found
# FANG not found
# DLR not found
# DFS not found
# DISH not found
# DIS not found
# DG not found
# DLTR not found
# D not found
# DPZ not found
# DOV not found
# DOW not found
# DTE not found
# DUK not found
# DD not found
# DXC not found
# EMN not found
# ETN not found
# EBAY not found
# ECL not found
# EIX not found
# EW not found
# EA not found
# ELV not found
# LLY not found
# EMR not found
# ENPH not found
# ETR not found
# EOG not found
# EPAM not found
# EQT not found
# EFX not found
# EQIX not found
# EQR not found
# ESS not found
# EL not found
# ETSY not found
# RE not found
# EVRG not found
# ES not found
# EXC not found
# EXPE not found
# EXPD not found
# EXR not found
# XOM not found
# FFIV not found
# FDS not found
# FICO not found
# FAST not found
# FRT not found
# FDX not found
# FITB not found
# FSLR not found
# FE not found
# FIS not found
# FI not found
# FLT not found
# FMC not found
# F not found
# FTNT not found
# FTV not found
# FOXA not found
# FOX not found
# BEN not found
# FCX not found
# GRMN not found
# IT not found
# GEHC not found
# GEN not found
# GNRC not found
# GD not found
# GE not found
# GIS not found
# GM not found
# GPC not found
# GILD not found
# GL not found
# GPN not found
# GS not found
# HAL not found
# HIG not found
# HAS not found
# HCA not found
# PEAK not found
# HSIC not found
# HSY not found
# HES not found
# HPE not found
# HLT not found
# HOLX not found
# HD not found
# HON not found
# HRL not found
# HST not found
# HWM not found
# HPQ not found
# HUM not found
# HBAN not found
# HII not found
# IBM not found
# IEX not found
# IDXX not found
# ITW not found
# ILMN not found
# INCY not found
# IR not found
# PODD not found
# INTC not found
# ICE not found
# IFF not found
# IP not found
# IPG not found
# INTU not found
# ISRG not found
# IVZ not found
# INVH not found
# IQV not found
# IRM not found
# JBHT not found
# JKHY not found
# J not found
# JNJ not found
# JCI not found
# JPM not found
# JNPR not found
# K not found
# KDP not found
# KEY not found
# KEYS not found
# KMB not found
# KIM not found
# KMI not found
# KLAC not found
# KHC not found
# KR not found
# LHX not found
# LH not found
# LRCX not found
# LW not found
# LVS not found
# LDOS not found
# LEN not found
# LNC not found
# LIN not found
# LYV not found
# LKQ not found
# LMT not found
# L not found
# LOW not found
# LYB not found
# MTB not found
# MRO not found
# MPC not found
# MKTX not found
# MAR not found
# MMC not found
# MLM not found
# MAS not found
# MA not found
# MTCH not found
# MKC not found
# MCD not found
# MCK not found
# MDT not found
# MRK not found
# META not found
# MET not found
# MTD not found
# MGM not found
# MCHP not found
# MU not found
# MSFT not found
# MAA not found
# MRNA not found
# MHK not found
# MOH not found
# TAP not found
# MDLZ not found
# MPWR not found
# MNST not found
# MCO not found
# MS not found
# MOS not found
# MSI not found
# MSCI not found
# NDAQ not found
# NTAP not found
# NFLX not found
# NWL not found
# NEM not found
# NWSA not found
# NWS not found
# NEE not found
# NKE not found
# NI not found
# NDSN not found
# NSC not found
# NTRS not found
# NOC not found
# NCLH not found
# NRG not found
# NUE not found
# NVDA not found
# NVR not found
# NXPI not found
# ORLY not found
# OXY not found
# ODFL not found
# OMC not found
# ON not found
# OKE not found
# ORCL not found
# OGN not found
# OTIS not found
# PCAR not found
# PKG not found
# PARA not found
# PH not found
# PAYX not found
# PAYC not found
# PYPL not found
# PNR not found
# PEP not found
# PFE not found
# PCG not found
# PM not found
# PSX not found
# PNW not found
# PXD not found
# PNC not found
# POOL not found
# PPG not found
# PPL not found
# PFG not found
# PG not found
# PGR not found
# PLD not found
# PRU not found
# PEG not found
# PTC not found
# PSA not found
# PHM not found
# QRVO not found
# PWR not found
# QCOM not found
# DGX not found
# RL not found
# RJF not found
# RTX not found
# O not found
# REG not found
# REGN not found
# RF not found
# RSG not found
# RMD not found
# RVTY not found
# RHI not found
# ROK not found
# ROL not found
# ROP not found
# ROST not found
# RCL not found
# SPGI not found
# CRM not found
# SBAC not found
# SLB not found
# STX not found
# SEE not found
# SRE not found
# NOW not found
# SHW not found
# SPG not found
# SWKS not found
# SJM not found
# SNA not found
# SEDG not found
# SO not found
# LUV not found
# SWK not found
# SBUX not found
# STT not found
# STLD not found
# STE not found
# SYK not found
# SYF not found
# SNPS not found
# SYY not found
# TMUS not found
# TROW not found
# TTWO not found
# TPR not found
# TRGP not found
# TGT not found
# TEL not found
# TDY not found
# TFX not found
# TER not found
# TSLA not found
# TXN not found
# TXT not found
# TMO not found
# TJX not found
# TSCO not found
# TT not found
# TDG not found
# TRV not found
# TRMB not found
# TFC not found
# TYL not found
# TSN not found
# USB not found
# UDR not found
# ULTA not found
# UNP not found
# UAL not found
# UPS not found
# URI not found
# UNH not found
# UHS not found
# VLO not found
# VTR not found
# VRSN not found
# VRSK not found
# VZ not found
# VRTX not found
# VFC not found
# VTRS not found
# VICI not found
# V not found
# VMC not found
# WAB not found
# WBA not found
# WMT not found
# WBD not found
# WM not found
# WAT not found
# WEC not found
# WFC not found
# WELL not found
# WST not found
# WDC not found
# WRK not found
# WY not found
# WHR not found
# WMB not found
# WTW not found
# GWW not found
# WYNN not found
# XEL not found
# XYL not found
# YUM not found
# ZBRA not found
# ZBH not found
# ZION not found
# ZTS not found
# Top Stocks: ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO']
# Bottom Stocks: ['VMC', 'WAB', 'WBA', 'WMT', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']

# %%
# Define the start and end dates
start_date = '2012-01-01'
end_date = '2023-06-08'

# Download financial data for the top and bottom stocks
all_stocks = top_stocks + bottom_stocks
stock_data = yf.download(top_stocks, start=start_date, end=end_date, group_by='ticker')
# Out:
# [*********************100%***********************]  25 of 25 completed

# %%
returns = stock_data.xs('Adj Close', axis=1, level=1, drop_level=False).pct_change()
returns=returns.droplevel(1,axis=1)
cor=returns.corr()
long=list(cor.sum(axis=1).sort_values()[:15].index)

# %%
# Calculate the weights for the long and short positions
long_weights = [1.0/len(long)] * len(long)
# Combine the long and short portfolios and weights
portfolio_stocks = long
portfolio_weights = long_weights 

# Calculate the daily returns for the portfolio
portfolio_returns = (returns[portfolio_stocks].fillna(0)).dot(portfolio_weights)
# Calculate the volatility of the portfolio
portfolio_volatility = np.std(portfolio_returns)

print("Low-correlation long portfolio volatility:", portfolio_volatility)
# Out:
# Low-correlation long portfolio volatility: 0.011201558794873244

# %%
# Calculate daily returns for each stock
returns = stock_data.xs('Adj Close', axis=1, level=1, drop_level=False).pct_change()
returns=returns.droplevel(1,axis=1)
# Calculate the correlation matrix
corr_matrix = returns.corr()
import numpy as np
# Find the stocks with the lowest correlation to each other
min_corr_stocks = []
min_corr = 0.3
for i, stock1 in enumerate(all_stocks):
    for j in range(i+1, len(all_stocks)):
        stock2 = all_stocks[j]
        corr = corr_matrix.loc[stock1, stock2]
        if corr < min_corr:
            min_corr_stocks.append(stock1)
            min_corr_stocks.append(stock2)

# Separate the low-correlation stocks into long and short portfolios
long_portfolio = [stock for stock in top_stocks if stock in min_corr_stocks]
short_portfolio = [stock for stock in bottom_stocks if stock in min_corr_stocks]

# Calculate the weights for the long and short positions
long_weights = [1.0/len(long_portfolio)] * len(long_portfolio)
short_weights = [-1.0/len(short_portfolio)] * len(short_portfolio)

# Combine the long and short portfolios and weights
portfolio_stocks = long_portfolio + short_portfolio
portfolio_weights = long_weights + short_weights

# Calculate the daily returns for the portfolio

portfolio_returns = (returns[portfolio_stocks].fillna(0)).dot(portfolio_weights)

# Calculate the volatility of the portfolio
portfolio_volatility = np.std(portfolio_returns)

print("Low-correlation long-short portfolio volatility:", portfolio_volatility)
# Out:
# Low-correlation long-short portfolio volatility: 0.004508961569998533

# %%
snp500 = yf.download(['SPY'], start=start_date, end=end_date, group_by='ticker')
snp500_returns=snp500['Close'].pct_change()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt
start_date = '2012-01-01'
end_date = '2023-06-05'
plt.plot((portfolio_returns+1).cumprod())
plt.plot((snp500_returns+1).cumprod())
#Absolutely beat S&P500

# %%
def sharpe(series):
    mean=series.mean()
    stdv=series.std()
    return np.sqrt(252)*mean/stdv
sharpe(portfolio_returns)
# Out:
# 0.9793824065185095

# %%
plt.plot((portfolio_returns+1).cumprod())
